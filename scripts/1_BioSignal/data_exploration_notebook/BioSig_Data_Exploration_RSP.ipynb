# %% [markdown]
# # Checking Datasets after each step processing

# %% [markdown]
# ## 1. After Processing

# %%
#%pip install xlrd

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import sweetviz as sv
import numpy as np
import sys
import re
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Set, List
import os
from datetime import datetime
sys.executable
# Out:
# '/home/vault/empkins/tpD/D02/.venv/bin/python'

# %% [markdown]
# # RSP

# %% [markdown]
# #### Read Data

# %% [markdown]
# #### Raw data with sampling rate 2000 or 500 miliseconds
# #### Pocessed in 1, 3, and 5 Minute window size

# %%
################################### After signal processing
######### 1 Minute
file_path_1 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_1_Minute.csv'
df_1M = pd.read_csv(file_path_1)
######### 3 Minute
file_path_3 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_3_Minute.csv'
df_3M = pd.read_csv(file_path_3)
######### 5 Minute
file_path_5 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_5_Minute.csv'
df_5M = pd.read_csv(file_path_5)

# %% [markdown]
# ## RSP Feature Glossary of 57 features
#
# ## Basic window stats (raw RSP amplitude)
#
# * **mean / median** — average / central tendency of the window (arbitrary units).
#   *Interpretation:* higher baseline vs. lower baseline breathing signal.
# * **std** — overall variability (dispersion).
#   *Interpretation:* more movement/variability in the window.
# * **min / max** — extremes in the window.
#   *Interpretation:* peak-to-peak amplitude bounds.
#
# ---
#
# ## RRV features (from breath-to-breath intervals)
#
# ### Time-domain
#
# * **RRV\_MeanBB** — mean breath-to-breath interval (s).
#   *Breathing rate (brpm) ≈ 60 / MeanBB.*
# * **RRV\_SDBB** — SD of BBIs (overall variability).
# * **RRV\_SDSD** — SD of successive BBI differences (short-term variability).
# * **RRV\_RMSSD** — sqrt(mean of squared successive BBI differences) (short-term variability).
# * **RRV\_MedianBB / RRV\_MadBB** — median BBI and its median absolute deviation.
# * **RRV\_CVBB / RRV\_CVSD / RRV\_MCVBB** — coefficient(s) of variation (scale-normalized variability).
# * **RRV\_SD1 / RRV\_SD2 / RRV\_SD2SD1** — Poincaré plot metrics:
#
#   * SD1: short-term variability (beat-to-beat).
#   * SD2: longer-term variability (trend).
#   * SD2/SD1: balance of long- vs short-term dynamics.
#
# ### Frequency-domain (power of BBI fluctuations)
#
# * **RRV\_VLF / RRV\_LF / RRV\_HF** — spectral power in very-low, low, and high bands (as defined in NeuroKit’s `rsp_rrv` on the BBI series).
#   *Interpretation:* relative dominance of slow vs faster variability components.
# * **RRV\_LFn / RRV\_HFn** — normalized LF/HF power.
# * **RRV\_LFHF** — LF/HF power ratio.
#   *Caution:* Physiological meaning differs from HRV; interpret within your task/context.
#
# ### Nonlinear/complexity
#
# * **RRV\_ApEn / RRV\_SampEn** — Approximate / Sample Entropy (regularity).
#   *Higher = more irregular/unpredictable breathing pattern; lower = more regular.*
#
# ---
#
# ## Scaling/fractal metrics
#
# ### DFA (detrended fluctuation analysis)
#
# * **RRV\_DFA\_alpha1** — short-range scaling exponent.
# * **RRV\_DFA\_alpha2** — long-range scaling exponent.
#
# ### MFDFA (multifractal) — computed separately for short (α1) and long (α2) scales
#
# * **RRV\_MFDFA\_alpha{1|2}\_Width** — spectrum width (α\_max − α\_min): overall multifractality strength. Larger = more heterogeneous scaling.
# * **…\_Peak** — location of the spectrum peak (dominant singularity exponent).
# * **…\_Mean / …\_Max** — average / maximum singularity exponent.
# * **…\_Delta** — spread measure around the peak (tail separation). Larger = broader tails.
# * **…\_Asymmetry** — left- vs right-skew of the spectrum (whether small or large fluctuations dominate).
# * **…\_Fluctuation / …\_Increment** — internal summary descriptors of fluctuation behavior across q-orders (larger values generally indicate stronger, less uniform scaling across moments).
# ---
#
# ## Metadata / demographics (per ID / window / phase)
#
# * **ID**
# * **gender** — W (female), M (male), D (diverse), m (trans).
# * **age** — in years.
# * **Diagnose** — Healthy / Depressed
# * **condition** — SHAM, CRADK, CR, ADK
# * **PHQ8-Score / PHQ9-Score** — self-report depression severity.
# * **previous\_depression\_diagnosis** — Ja/Nein (history).
# * **RSP\_measuring / ECG\_measuring / EMG\_measuring** — Ja/Nein flags (data availability).
# * **Including\_masseter** — Ja/Nein (EMG channel inclusion).
# * **time** — timestamp of the window start/center (as stored in your phase-assigned files).
# * **phase** — coping, training, emotion\_induction\_1, emotion\_induction\_2, latency
#
#
#
# ## Missed participants due to ack of data:
# `005`, `074`, `516`, `641`, `673`, `828`

# %%
################################### After phase assignment
######### 1 Minute
file_path_1 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_1_Minute_phase_assigned.csv'
df_1M = pd.read_csv(file_path_1)
######### 3 Minute
file_path_3 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_3_Minute_phase_assigned.csv'
df_3M = pd.read_csv(file_path_3)
######### 5 Minute
file_path_5 = '/home/vault/empkins/tpD/D02/Students/Yasaman/BioSig_data/feature_extracted_data/RSP/RSP_5_Minute_phase_assigned.csv'
df_5M = pd.read_csv(file_path_5)

# %% [markdown]
# #### Information

# %%
# Dimension
print(f"Shape 1 Minute: {df_1M.shape}")
print(f"Shape 3 Minute: {df_3M.shape}")
print(f"Shape 5 Minute: {df_5M.shape}")
# Out:
# Shape 1 Minute: (20245, 48)
# Shape 3 Minute: (6664, 57)
# Shape 5 Minute: (3950, 57)

# %%
print(f"---------------\nFeatures in 1 minute: \n{df_1M.columns.tolist()}\n")
print(f"---------------\nFeatures in 3 minute: \n{df_3M.columns.tolist()}\n")
print(f"---------------\nFeatures in 5 minute: \n{df_5M.columns.tolist()}\n")
# Out:
# ---------------
# Features in 1 minute:
# ['RRV_RMSSD', 'RRV_MeanBB', 'RRV_SDBB', 'RRV_SDSD', 'RRV_CVBB', 'RRV_CVSD', 'RRV_MedianBB', 'RRV_MadBB', 'RRV_MCVBB', 'RRV_VLF', 'RRV_LF', 'RRV_HF', 'RRV_LFHF', 'RRV_LFn', 'RRV_HFn', 'RRV_SD1', 'RRV_SD2', 'RRV_SD2SD1', 'RRV_ApEn', 'RRV_SampEn', 'mean', 'std', 'min', 'max', 'median', 'ID', 'RRV_DFA_alpha2', 'RRV_MFDFA_alpha2_Width', 'RRV_MFDFA_alpha2_Peak', 'RRV_MFDFA_alpha2_Mean', 'RRV_MFDFA_alpha2_Max', 'RRV_MFDFA_alpha2_Delta', 'RRV_MFDFA_alpha2_Asymmetry', 'RRV_MFDFA_alpha2_Fluctuation', 'RRV_MFDFA_alpha2_Increment', 'PHQ8-Score', 'previous_depression_diagnosis', 'PHQ9-Score', 'condition', 'Diagnose', 'gender', 'age', 'EMG_measuring', 'RSP_measuring', 'ECG_measuring', 'Including_masseter', 'time', 'phase']
#
# ---------------
# Features in 3 minute:
# ['RRV_RMSSD', 'RRV_MeanBB', 'RRV_SDBB', 'RRV_SDSD', 'RRV_CVBB', 'RRV_CVSD', 'RRV_MedianBB', 'RRV_MadBB', 'RRV_MCVBB', 'RRV_VLF', 'RRV_LF', 'RRV_HF', 'RRV_LFHF', 'RRV_LFn', 'RRV_HFn', 'RRV_SD1', 'RRV_SD2', 'RRV_SD2SD1', 'RRV_ApEn', 'RRV_SampEn', 'mean', 'std', 'min', 'max', 'median', 'ID', 'RRV_DFA_alpha2', 'RRV_MFDFA_alpha2_Width', 'RRV_MFDFA_alpha2_Peak', 'RRV_MFDFA_alpha2_Mean', 'RRV_MFDFA_alpha2_Max', 'RRV_MFDFA_alpha2_Delta', 'RRV_MFDFA_alpha2_Asymmetry', 'RRV_MFDFA_alpha2_Fluctuation', 'RRV_MFDFA_alpha2_Increment', 'RRV_DFA_alpha1', 'RRV_MFDFA_alpha1_Width', 'RRV_MFDFA_alpha1_Peak', 'RRV_MFDFA_alpha1_Mean', 'RRV_MFDFA_alpha1_Max', 'RRV_MFDFA_alpha1_Delta', 'RRV_MFDFA_alpha1_Asymmetry', 'RRV_MFDFA_alpha1_Fluctuation', 'RRV_MFDFA_alpha1_Increment', 'PHQ8-Score', 'previous_depression_diagnosis', 'PHQ9-Score', 'condition', 'Diagnose', 'gender', 'age', 'EMG_measuring', 'RSP_measuring', 'ECG_measuring', 'Including_masseter', 'time', 'phase']
#
# ---------------
# Features in 5 minute:
# ['RRV_RMSSD', 'RRV_MeanBB', 'RRV_SDBB', 'RRV_SDSD', 'RRV_CVBB', 'RRV_CVSD', 'RRV_MedianBB', 'RRV_MadBB', 'RRV_MCVBB', 'RRV_VLF', 'RRV_LF', 'RRV_HF', 'RRV_LFHF', 'RRV_LFn', 'RRV_HFn', 'RRV_SD1', 'RRV_SD2', 'RRV_SD2SD1', 'RRV_ApEn', 'RRV_SampEn', 'RRV_DFA_alpha2', 'RRV_MFDFA_alpha2_Width', 'RRV_MFDFA_alpha2_Peak', 'RRV_MFDFA_alpha2_Mean', 'RRV_MFDFA_alpha2_Max', 'RRV_MFDFA_alpha2_Delta', 'RRV_MFDFA_alpha2_Asymmetry', 'RRV_MFDFA_alpha2_Fluctuation', 'RRV_MFDFA_alpha2_Increment', 'mean', 'std', 'min', 'max', 'median', 'ID', 'RRV_DFA_alpha1', 'RRV_MFDFA_alpha1_Width', 'RRV_MFDFA_alpha1_Peak', 'RRV_MFDFA_alpha1_Mean', 'RRV_MFDFA_alpha1_Max', 'RRV_MFDFA_alpha1_Delta', 'RRV_MFDFA_alpha1_Asymmetry', 'RRV_MFDFA_alpha1_Fluctuation', 'RRV_MFDFA_alpha1_Increment', 'PHQ8-Score', 'previous_depression_diagnosis', 'PHQ9-Score', 'condition', 'Diagnose', 'gender', 'age', 'EMG_measuring', 'RSP_measuring', 'ECG_measuring', 'Including_masseter', 'time', 'phase']

# %% [markdown]
# #### Missing in Window Size 1 Minute

# %%
Missing_features_1_Min = list(set(df_5M.columns) - set(df_1M.columns))

print(f"Features are not contain in 1 Min: number = {len(Missing_features_1_Min)}\nMissing Features: {Missing_features_1_Min}")
# Out:
# Features are not contain in 1 Min: number = 9
# Missing Features: ['RRV_MFDFA_alpha1_Peak', 'RRV_MFDFA_alpha1_Width', 'RRV_MFDFA_alpha1_Fluctuation', 'RRV_MFDFA_alpha1_Delta', 'RRV_MFDFA_alpha1_Increment', 'RRV_MFDFA_alpha1_Max', 'RRV_DFA_alpha1', 'RRV_MFDFA_alpha1_Asymmetry', 'RRV_MFDFA_alpha1_Mean']

# %% [markdown]
# #### Why 1‑minute RSP windows only yield MFDFA/DFA features
#
#  With 1‑minute windows there are usually too few breaths (≈12–20) to compute many RRV metrics reliably. NeuroKit’s `nk.rsp_rrv()` skips metrics that need longer breath‑to‑breath (BBI) series (entropy, frequency domain, Poincaré, etc.). The ones that survive are mostly MFDFA/DFA features, which tolerate shorter series.
#
# ##### What `RSP_Signal_Processing.py` does
#
# * Clean signal → detect peaks → fix peaks → compute instantaneous respiration rate (`rsp_rate`) → call `nk.rsp_rrv(...)`.
# * If `nk.rsp_rrv()` can’t compute a metric (e.g., not enough samples for embedding/PSD), it raises errors like
#   *“dimension \* delay should be lower than the length of the signal”* (common in entropy/complexity).
# * The try/except catches these, logs a warning, and proceeds—leaving only the features that **did** compute (mostly `RRV_MFDFA_*` and `RRV_DFA_alpha1`).
#
# ##### Why 1‑minute is fragile
#
# * **Time‑domain/entropy features** (RMSSD/SDSD/ApEn/SampEn/SD1/SD2…) require **enough BBIs**; short windows don’t have them.
# * **Frequency‑domain features** (VLF/LF/HF/LF/HF ratio) need sufficient cycles to estimate a spectrum.

# %%
df_1M.head()
# Out:
#      RRV_RMSSD   RRV_MeanBB     RRV_SDBB     RRV_SDSD  RRV_CVBB  RRV_CVSD  \
# 0  3475.717754  3551.964286  2574.618840  3617.515477  0.724844  0.978534
# 1  1449.067446  3126.200000  1069.084101  1502.284535  0.341976  0.463524
# 2  1145.499038  2806.911765   993.267512  1181.948617  0.353865  0.408099
# 3   792.294091  2955.444444   531.775768   815.990675  0.179931  0.268080
# 4   992.100761  2281.413043   730.943345  1014.801364  0.320391  0.434862
#
#    RRV_MedianBB   RRV_MadBB  RRV_MCVBB  RRV_VLF  ...  condition  Diagnose  \
# 0       2516.25  1030.40700   0.409501      0.0  ...         CR   Healthy
# 1       2791.50   526.32300   0.188545      0.0  ...         CR   Healthy
# 2       2685.50   750.19560   0.279350      0.0  ...         CR   Healthy
# 3       2951.25   580.80855   0.196801      0.0  ...         CR   Healthy
# 4       2355.50   826.54950   0.350902      0.0  ...         CR   Healthy
#
#    gender   age  EMG_measuring  RSP_measuring  ECG_measuring  \
# 0       W  22.0           Nein             Ja             Ja
# 1       W  22.0           Nein             Ja             Ja
# 2       W  22.0           Nein             Ja             Ja
# 3       W  22.0           Nein             Ja             Ja
# 4       W  22.0           Nein             Ja             Ja
#
#    Including_masseter                     time  phase
# 0                Nein  2000-01-01 17:12:16.328    NaN
# 1                Nein  2000-01-01 17:13:16.328    NaN
# 2                Nein  2000-01-01 17:14:16.328    NaN
# 3                Nein  2000-01-01 17:15:16.328    NaN
# 4                Nein  2000-01-01 17:16:16.328    NaN
#
# [5 rows x 48 columns]

# %%
df_3M.head()
# Out:
#      RRV_RMSSD   RRV_MeanBB     RRV_SDBB     RRV_SDSD  RRV_CVBB  RRV_CVSD  \
# 0  2668.541461  3355.711538  1954.977111  2694.892099  0.582582  0.795224
# 1  1282.052450  2686.746032   879.583451  1292.352591  0.327379  0.477177
# 2  1644.647166  2897.666667  1132.939628  1658.359423  0.390983  0.567576
# 3   635.091911  2580.955224   466.188159   639.958388  0.180626  0.246069
# 4  1368.448012  2917.983051   883.060587  1380.344751  0.302627  0.468971
#
#    RRV_MedianBB  RRV_MadBB  RRV_MCVBB   RRV_VLF  ...  condition  Diagnose  \
# 0       2921.25  905.12730   0.309842  0.001654  ...         CR   Healthy
# 1       2723.50  603.41820   0.221560  0.005192  ...         CR   Healthy
# 2       2592.00  520.02195   0.200626  0.012386  ...         CR   Healthy
# 3       2545.50  510.75570   0.200650  0.003043  ...         CR   Healthy
# 4       2728.00  590.81610   0.216575  0.007040  ...         CR   Healthy
#
#    gender   age  EMG_measuring  RSP_measuring  ECG_measuring  \
# 0       W  22.0           Nein             Ja             Ja
# 1       W  22.0           Nein             Ja             Ja
# 2       W  22.0           Nein             Ja             Ja
# 3       W  22.0           Nein             Ja             Ja
# 4       W  22.0           Nein             Ja             Ja
#
#    Including_masseter                     time                phase
# 0                Nein  2000-01-01 17:12:16.328                  NaN
# 1                Nein  2000-01-01 17:15:16.328                  NaN
# 2                Nein  2000-01-01 17:18:16.328                  NaN
# 3                Nein  2000-01-01 17:21:16.328              latency
# 4                Nein  2000-01-01 17:24:16.328  emotion_induction_1
#
# [5 rows x 57 columns]

# %%
df_5M.head()
# Out:
#      RRV_RMSSD   RRV_MeanBB     RRV_SDBB     RRV_SDSD  RRV_CVBB  RRV_CVSD  \
# 0  2018.388473  3045.776042  1543.116068  2028.950962  0.506641  0.662684
# 1  1603.507792  2812.385714  1065.765958  1611.271065  0.378954  0.570159
# 2  1109.946644  2814.100962   729.120695  1115.343315  0.259095  0.394423
# 3  1563.238295  2966.778351  1117.397490  1571.210909  0.376637  0.526914
# 4  1203.579665  3017.824742   849.862556  1209.896356  0.281614  0.398824
#
#    RRV_MedianBB  RRV_MadBB  RRV_MCVBB   RRV_VLF  ...  condition  Diagnose  \
# 0       2810.75   758.3499   0.269803  0.004800  ...         CR   Healthy
# 1       2571.50   524.0991   0.203811  0.014473  ...         CR   Healthy
# 2       2713.75   475.1733   0.175098  0.011332  ...         CR   Healthy
# 3       2629.00   805.0518   0.306220  0.009836  ...         CR   Healthy
# 4       2950.50   598.9704   0.203006  0.016246  ...         CR   Healthy
#
#    gender   age  EMG_measuring  RSP_measuring  ECG_measuring  \
# 0       W  22.0           Nein             Ja             Ja
# 1       W  22.0           Nein             Ja             Ja
# 2       W  22.0           Nein             Ja             Ja
# 3       W  22.0           Nein             Ja             Ja
# 4       W  22.0           Nein             Ja             Ja
#
#    Including_masseter                     time  phase
# 0                Nein  2000-01-01 17:12:16.328    NaN
# 1                Nein  2000-01-01 17:17:16.328    NaN
# 2                Nein  2000-01-01 17:22:16.328    NaN
# 3                Nein  2000-01-01 17:27:16.328    NaN
# 4                Nein  2000-01-01 17:32:16.328    NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# ##### Participants & Conditions:

# %%
print(f"Number of participants 1 minute: {len(df_1M['ID'].unique())}")
print(f"Unique Condition 1 minute: {df_1M['condition'].unique()}\n")

print(f"Number of participants 3 minute: {len(df_3M['ID'].unique())}")
print(f"Unique Condition 3 minute: {df_3M['condition'].unique()}\n")

print(f"Number of participants 5 minute: {len(df_5M['ID'].unique())}")
print(f"Unique Condition 5 minute: {df_5M['condition'].unique()}\n")
# Out:
# Number of participants 1 minute: 253
# Unique Condition 1 minute: ['CR' 'CRADK' 'ADK' 'SHAM']
#
# Number of participants 3 minute: 253
# Unique Condition 3 minute: ['CR' 'CRADK' 'ADK' 'SHAM']
#
# Number of participants 5 minute: 253
# Unique Condition 5 minute: ['CR' 'CRADK' 'ADK' 'SHAM']

# %% [markdown]
# #### Phase Report

# %%
# General phase Information from app.csv file
RCT_path = '/home/vault/empkins/tpD/D02/Students/Yasaman/RCT_Data_Info/result/RCT_Phase_Info.csv'
RCT_phase_df = pd.read_csv(RCT_path)
drop_Ids = ['005', '074', '516', '641', '673', '828']
RCT_phase_df['ID'] = RCT_phase_df['ID'].astype(str).str.zfill(3)
RCT_phase_df  = RCT_phase_df[~RCT_phase_df['ID'].isin(drop_Ids)].copy()

# After phase assignment
RCT_path = '/home/vault/empkins/tpD/D02/Students/Yasaman/RCT_Data_Info/result/RCT_Phase_Info_after_phase_assignment.csv'
RCT_phase_df_phase = pd.read_csv(RCT_path)
df_phase_info_RSP = RCT_phase_df_phase[RCT_phase_df_phase["Modality"].str.upper() == "RSP"].copy()
df_phase_info_RSP.head()
# Out:
#   Modality Window_Size  ID                Phase               Start_Time  \
# 0      RSP        1min   4               coping  2000-01-01 17:36:16.328
# 1      RSP        1min   4             training  2000-01-01 18:20:16.328
# 2      RSP        1min   4  emotion_induction_1  2000-01-01 17:25:16.328
# 3      RSP        1min   4  emotion_induction_2  2000-01-01 18:13:16.328
# 4      RSP        1min   4              latency  2000-01-01 17:21:16.328
#
#                   End_Time         Duration
# 0  2000-01-01 18:07:16.328  0 days 00:31:00
# 1  2000-01-01 18:44:16.328  0 days 00:24:00
# 2  2000-01-01 17:26:16.328  0 days 00:01:00
# 3  2000-01-01 18:14:16.328  0 days 00:01:00
# 4  2000-01-01 17:23:16.328  0 days 00:02:00

# %% [markdown]
# ##### Missing participants per window size (RSP)

# %%
def _norm_window_size(s) -> str:
    """Extract numeric part from values like '1min', '3 min', 5, 5.0 -> '1','3','5','5'."""
    if pd.isna(s):
        return np.nan
    # already numeric?
    if isinstance(s, (int, float, np.integer, np.floating)):
        return str(int(s)) if float(s).is_integer() else str(s)
    # string case: pull first number
    m = re.search(r'(\d+(\.\d+)?)', str(s))
    return m.group(1) if m else str(s)

df_phase_info_RSP["Window_Size"] = df_phase_info_RSP["Window_Size"].map(_norm_window_size)

# Standardize columns
RCT_phase_df.columns = [c.lower() for c in RCT_phase_df.columns]
df_phase_info_RSP.columns  = [c.lower() for c in df_phase_info_RSP.columns]

# Ensure consistent types
RCT_phase_df["id"] = RCT_phase_df["id"].astype(str).str.zfill(3)
df_phase_info_RSP["id"]  = df_phase_info_RSP["id"].astype(str).str.zfill(3)
df_phase_info_RSP["window_size"] = df_phase_info_RSP["window_size"].astype(str)

# Keep only RSP rows in the AFTER file
after_rsp = df_phase_info_RSP[df_phase_info_RSP["modality"].str.upper() == "RSP"].copy()

def missing_participants_per_window(before: pd.DataFrame, after_rsp: pd.DataFrame) -> pd.DataFrame:
    """Compute % missing participants per window size for RSP; include ID lists."""
    baseline_ids: Set[str] = set(before["id"].unique())
    window_sizes = sorted(after_rsp["window_size"].astype(str).unique(), key=lambda x: float(x))

    rows = []
    for ws in window_sizes:
        ids_after_ws = set(after_rsp[after_rsp["window_size"] == ws]["id"].unique())
        missing_ids_ws = sorted(list(baseline_ids - ids_after_ws))
        pct_missing_ws = (len(missing_ids_ws) / len(baseline_ids) * 100.0) if baseline_ids else 0.0

        rows.append({
            "Modality": "RSP",
            "Window_Size": ws,
            "Total_Baseline_IDs": len(baseline_ids),
            "Present_After": len(ids_after_ws),
            "Missing_Count": len(missing_ids_ws),
            "Missing_%": round(pct_missing_ws, 2),
            "Missing_IDs": missing_ids_ws,
        })
    return pd.DataFrame(rows)

# 2) Run it and see the table
missing_df = missing_participants_per_window(RCT_phase_df, df_phase_info_RSP)
missing_df.head()
# Out:
#   Modality Window_Size  Total_Baseline_IDs  Present_After  Missing_Count  \
# 0      RSP           1                 253            253              0
# 1      RSP           3                 253            253              0
# 2      RSP           5                 253            253              0
#
#    Missing_% Missing_IDs
# 0        0.0          []
# 1        0.0          []
# 2        0.0          []

# %% [markdown]
# ### Report from Phase

# %%
def phase_level_missingness(before: pd.DataFrame, after_rsp: pd.DataFrame, phases: List[str]) -> pd.DataFrame:
    # standardize column names
    before.columns = [c.lower() for c in before.columns]
    after_rsp.columns = [c.lower() for c in after_rsp.columns]

    # ensure ID is string
    before["id"] = before["id"].astype(str).str.zfill(3)
    after_rsp["id"] = after_rsp["id"].astype(str).str.zfill(3)

    # normalize window_size
    after_rsp["window_size"] = after_rsp["window_size"].astype(str).str.extract(r"(\d+)")[0]

    # convert duration to timedelta
    before["duration_td"] = pd.to_timedelta(before["duration"], errors="coerce")
    after_rsp["duration_td"] = pd.to_timedelta(after_rsp["duration"], errors="coerce")

    # all unique participants before assignment
    baseline_ids: Set[str] = set(before["id"].unique())
    window_sizes = sorted(after_rsp["window_size"].dropna().unique(), key=lambda x: float(x))

    records = []
    for phase in phases:
        ids_before_phase = set(before.loc[before["phase"] == phase, "id"].unique())
        before_missing_ids = sorted(list(baseline_ids - ids_before_phase))

        for ws in window_sizes:
            subset = after_rsp[(after_rsp["window_size"] == ws) & (after_rsp["phase"] == phase)]
            ids_after_phase_ws = set(subset.loc[subset["duration_td"].notna(), "id"].unique())

            after_missing_ids = sorted(list(baseline_ids - ids_after_phase_ws))
            newly_missing = sorted(list(ids_before_phase - ids_after_phase_ws))

            records.append({
                "Phase": phase,
                "Window_Size": ws,
                "Baseline_IDs": len(baseline_ids), # Total number of unique participants in the BEFORE dataset (used as reference set)
                "Have_Phase_Before": len(ids_before_phase), # Number of participants who had this phase in the BEFORE dataset (raw phase counts)
                "Missing_Before_Count": len(before_missing_ids), # Number of participants who did NOT have this phase in the BEFORE dataset
                "Missing_Before_%": round((len(before_missing_ids) / len(baseline_ids) * 100.0) if baseline_ids else 0.0, 2), # Percent of participants who were missing this phase BEFORE phase assignment
                "Have_Phase_After": len(ids_after_phase_ws),  # Number of participants who have this phase in the AFTER dataset (after phase assignment)
                "Missing_After_Count": len(after_missing_ids), # Number of participants who are missing this phase AFTER phase assignment
                "Missing_After_%": round((len(after_missing_ids) / len(baseline_ids) * 100.0) if baseline_ids else 0.0, 2), # Percent of participants missing this phase AFTER phase assignment
                "Newly_Missing_Count": len(newly_missing), # Number of participants who had this phase BEFORE but lost it AFTER phase assignment
                "Newly_Missing_%Among_Those_Who_Had_Before": round((len(newly_missing) / len(ids_before_phase) * 100.0) if ids_before_phase else 0.0, 2), # Percent of newly missing cases *among those who had the phase before*
                "Missing_Before_IDs": before_missing_ids,
                "Missing_After_IDs": after_missing_ids,
                "Newly_Missing_IDs": newly_missing,
            })
    return pd.DataFrame(records)


all_phases = ["coping", "training", "emotion_induction_1", "emotion_induction_2", "latency"]
result = phase_level_missingness(RCT_phase_df, df_phase_info_RSP, all_phases)
result.head(15)
# Out:
#                   Phase Window_Size  Baseline_IDs  Have_Phase_Before  \
# 0                coping           1           253                253
# 1                coping           3           253                253
# 2                coping           5           253                253
# 3              training           1           253                253
# 4              training           3           253                253
# 5              training           5           253                253
# 6   emotion_induction_1           1           253                253
# 7   emotion_induction_1           3           253                253
# 8   emotion_induction_1           5           253                253
# 9   emotion_induction_2           1           253                253
# 10  emotion_induction_2           3           253                253
# 11  emotion_induction_2           5           253                253
# 12              latency           1           253                253
# 13              latency           3           253                253
# 14              latency           5           253                253
#
#     Missing_Before_Count  Missing_Before_%  Have_Phase_After  \
# 0                      0               0.0               229
# 1                      0               0.0               225
# 2                      0               0.0               219
# 3                      0               0.0               236
# 4                      0               0.0               233
# 5                      0               0.0               227
# 6                      0               0.0               248
# 7                      0               0.0               182
# 8                      0               0.0               109
# 9                      0               0.0               217
# 10                     0               0.0               136
# 11                     0               0.0                75
# 12                     0               0.0               250
# 13                     0               0.0               245
# 14                     0               0.0               183
#
#     Missing_After_Count  Missing_After_%  Newly_Missing_Count  \
# 0                    24             9.49                   24
# 1                    28            11.07                   28
# 2                    34            13.44                   34
# 3                    17             6.72                   17
# 4                    20             7.91                   20
# 5                    26            10.28                   26
# 6                     5             1.98                    5
# 7                    71            28.06                   71
# 8                   144            56.92                  144
# 9                    36            14.23                   36
# 10                  117            46.25                  117
# 11                  178            70.36                  178
# 12                    3             1.19                    3
# 13                    8             3.16                    8
# 14                   70            27.67                   70
#
#     Newly_Missing_%Among_Those_Who_Had_Before Missing_Before_IDs  \
# 0                                        9.49                 []
# 1                                       11.07                 []
# 2                                       13.44                 []
# 3                                        6.72                 []
# 4                                        7.91                 []
# 5                                       10.28                 []
# 6                                        1.98                 []
# 7                                       28.06                 []
# 8                                       56.92                 []
# 9                                       14.23                 []
# 10                                      46.25                 []
# 11                                      70.36                 []
# 12                                       1.19                 []
# 13                                       3.16                 []
# 14                                      27.67                 []
#
#                                     Missing_After_IDs  \
# 0   [1025, 1040, 1060, 1068, 1111, 156, 242, 270, ...
# 1   [1022, 1025, 1040, 1060, 1068, 1111, 156, 242,...
# 2   [1022, 1025, 1040, 1060, 1068, 1111, 125, 156,...
# 3   [1022, 1034, 1053, 1075, 263, 320, 453, 467, 6...
# 4   [1016, 1022, 1034, 1053, 1075, 137, 263, 320, ...
# 5   [1016, 1022, 1034, 1053, 1075, 119, 137, 155, ...
# 6                           [115, 430, 467, 741, 910]
# 7   [013, 094, 100, 1014, 1034, 1037, 1040, 1053, ...
# 8   [004, 013, 028, 038, 060, 077, 094, 100, 1016,...
# 9   [1022, 1025, 1034, 1053, 1060, 1075, 121, 142,...
# 10  [008, 038, 052, 094, 100, 1006, 1022, 1025, 10...
# 11  [013, 028, 052, 077, 094, 096, 100, 1006, 1014...
# 12                                    [115, 430, 467]
# 13           [115, 240, 287, 327, 430, 467, 910, 911]
# 14  [004, 007, 052, 096, 1006, 1017, 1029, 1037, 1...
#
#                                     Newly_Missing_IDs
# 0   [1025, 1040, 1060, 1068, 1111, 156, 242, 270, ...
# 1   [1022, 1025, 1040, 1060, 1068, 1111, 156, 242,...
# 2   [1022, 1025, 1040, 1060, 1068, 1111, 125, 156,...
# 3   [1022, 1034, 1053, 1075, 263, 320, 453, 467, 6...
# 4   [1016, 1022, 1034, 1053, 1075, 137, 263, 320, ...
# 5   [1016, 1022, 1034, 1053, 1075, 119, 137, 155, ...
# 6                           [115, 430, 467, 741, 910]
# 7   [013, 094, 100, 1014, 1034, 1037, 1040, 1053, ...
# 8   [004, 013, 028, 038, 060, 077, 094, 100, 1016,...
# 9   [1022, 1025, 1034, 1053, 1060, 1075, 121, 142,...
# 10  [008, 038, 052, 094, 100, 1006, 1022, 1025, 10...
# 11  [013, 028, 052, 077, 094, 096, 100, 1006, 1014...
# 12                                    [115, 430, 467]
# 13           [115, 240, 287, 327, 430, 467, 910, 911]
# 14  [004, 007, 052, 096, 1006, 1017, 1029, 1037, 1...

# %%
# Ensure duration is a Timedelta object
RCT_phase_df["duration"] = pd.to_timedelta(RCT_phase_df["duration"], errors="coerce")
df_phase_info_RSP["duration"] = pd.to_timedelta(df_phase_info_RSP["duration"], errors="coerce")

def bar_phase_total_durations(before: pd.DataFrame, after_rsp: pd.DataFrame, phases: List[str]) -> None:
    """
    Plots total phase durations (in minutes) for each phase, comparing BEFORE and AFTER phase assignment,
    for each window size (e.g., 1, 3, 5 min).
    """
    # Sum durations per phase (BEFORE)
    before_sum = (before.dropna(subset=["duration"])
                         .groupby("phase")["duration"]
                         .sum()
                         .reindex(phases))
    before_total_min = before_sum.dt.total_seconds() / 60.0

    # Sum durations per window size × phase (AFTER)
    after_sum = (after_rsp.dropna(subset=["duration"])
                         .groupby(["window_size", "phase"])["duration"]
                         .sum()
                         .unstack("phase")
                         .reindex(columns=phases)
                         .sort_index(key=lambda idx: [float(i) for i in idx]))
    after_total_min = after_sum.applymap(lambda td: td.total_seconds() / 60.0 if pd.notnull(td) else np.nan)

    # Plot per window size
    for ws in after_total_min.index:
        x = np.arange(len(phases))
        width = 0.35
        fig = plt.figure(figsize=(9, 5))
        plt.bar(x - width/2, before_total_min.values, width, label="Before")
        plt.bar(x + width/2, after_total_min.loc[ws, phases].values, width, label=f"After (WS={ws} min)")
        plt.xticks(ticks=x, labels=[p.replace("_", "\n") for p in phases])
        plt.ylabel("Total Phase Duration (minutes)")
        plt.title(f"Total Phase Duration — Before vs After (RSP, Window Size = {ws} min)")
        plt.legend()
        plt.tight_layout()
        plt.show()



bar_phase_total_durations(RCT_phase_df, df_phase_info_RSP, all_phases)
# Out:
# /tmp/ipykernel_408675/2929101524.py:24: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   after_total_min = after_sum.applymap(lambda td: td.total_seconds() / 60.0 if pd.notnull(td) else np.nan)

# %%
def bar_phase_total_durations_split_subplots(before: pd.DataFrame, after_rsp: pd.DataFrame, phases: List[str]) -> None:
    """
    For each window size, creates a figure with 5 subplots (one for each phase), 
    comparing total durations (in minutes) before vs after phase assignment.
    """
    # Sum durations per phase (BEFORE)
    before_sum = (before.dropna(subset=["duration"])
                         .groupby("phase")["duration"]
                         .sum()
                         .reindex(phases))
    before_total_min = before_sum.dt.total_seconds() / 60.0

    # Sum durations per window size × phase (AFTER)
    after_sum = (after_rsp.dropna(subset=["duration"])
                         .groupby(["window_size", "phase"])["duration"]
                         .sum()
                         .unstack("phase")
                         .reindex(columns=phases)
                         .sort_index(key=lambda idx: [float(i) for i in idx]))
    after_total_min = after_sum.applymap(lambda td: td.total_seconds() / 60.0 if pd.notnull(td) else np.nan)

    # Plot for each window size
    for ws in after_total_min.index:
        fig, axs = plt.subplots(nrows=1, ncols=len(phases), figsize=(20, 5), sharey=False)
        fig.suptitle(f"Total Phase Duration — Before vs After (RSP, Window Size = {ws} min)", fontsize=14)

        for i, phase in enumerate(phases):
            ax = axs[i]
            before_val = before_total_min[phase]
            after_val = after_total_min.loc[ws, phase]

            bars = ax.bar([0, 1], [before_val, after_val], width=0.6, color=["steelblue", "darkorange"])
            ax.set_title(phase.replace("_", "\n"))
            ax.set_xticks([0, 1])
            ax.set_xticklabels(["Before", "After"])
            ax.set_ylabel("Total Duration (min)")
            ax.grid(axis="y", linestyle="--", alpha=0.5)

            # Annotate values
            for bar in bars:
                yval = bar.get_height()
                ax.text(bar.get_x() + bar.get_width()/2, yval + 50, f"{yval:.0f}", ha="center", va="bottom", fontsize=9)

        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()


bar_phase_total_durations_split_subplots(RCT_phase_df, df_phase_info_RSP, all_phases)
# Out:
# /tmp/ipykernel_408675/3284086848.py:20: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   after_total_min = after_sum.applymap(lambda td: td.total_seconds() / 60.0 if pd.notnull(td) else np.nan)

# %%
# Make sure duration_td is parsed
df_phase_info_RSP["duration_td"] = pd.to_timedelta(df_phase_info_RSP["duration"], errors="coerce")

# Standardize column names
df_phase_info_RSP.columns = [c.lower() for c in df_phase_info_RSP.columns]
df_phase_info_RSP["window_size"] = df_phase_info_RSP["window_size"].astype(str).str.extract(r"(\d+)")[0]

# Define phase order (optional, for cleaner output)
phases = ["coping", "training", "emotion_induction_1", "emotion_induction_2", "latency"]

# Count total and missing entries
summary = (
    df_phase_info_RSP
    .groupby(["window_size", "phase"])
    .agg(
        total_entries=("duration_td", "count"),    # non-missing
        total_rows=("duration", "size"),           # all rows
        missing_count=("duration_td", lambda x: x.isna().sum())
    )
    .reset_index()
)

# Calculate percentage
summary["missing_%"] = (summary["missing_count"] / summary["total_rows"]) * 100
summary["missing_%"] = summary["missing_%"].round(2)

# Optional: reorder phases
summary["phase"] = pd.Categorical(summary["phase"], categories=phases, ordered=True)
summary = summary.sort_values(["window_size", "phase"])

# Show the summary
summary = summary[["window_size", "phase", "total_rows", "missing_count", "missing_%"]]
summary.reset_index(drop=True, inplace=True)
summary.head(15)
# Out:
#    window_size                phase  total_rows  missing_count  missing_%
# 0            1               coping         253             24       9.49
# 1            1             training         253             17       6.72
# 2            1  emotion_induction_1         253              5       1.98
# 3            1  emotion_induction_2         253             36      14.23
# 4            1              latency         253              3       1.19
# 5            3               coping         253             28      11.07
# 6            3             training         253             20       7.91
# 7            3  emotion_induction_1         253             71      28.06
# 8            3  emotion_induction_2         253            117      46.25
# 9            3              latency         253              8       3.16
# 10           5               coping         253             34      13.44
# 11           5             training         253             26      10.28
# 12           5  emotion_induction_1         253            144      56.92
# 13           5  emotion_induction_2         253            178      70.36
# 14           5              latency         253             70      27.67

# %%
def missingness_report(df: pd.DataFrame) -> pd.DataFrame:
    """
    Returns a one-row DataFrame where each column contains the percentage of missing values
    for that feature in the input DataFrame.
    """
    missing_pct = df.isnull().mean() * 100  # calculate % missing
    missing_pct_rounded = missing_pct.round(2)  # round for readability
    return pd.DataFrame([missing_pct_rounded], index=["Missing_%"])

# %%
print("---------------------------- Missing value % 1 Minute ---------------------------- \n")
missing_report = missingness_report(df_1M)
missing_report.T.sort_values("Missing_%", ascending=False)  # optional: sort top missing
# Out:
# ---------------------------- Missing value % 1 Minute ----------------------------
#                                Missing_%
# RRV_MFDFA_alpha2_Asymmetry         98.91
# RRV_MFDFA_alpha2_Fluctuation       98.91
# RRV_MFDFA_alpha2_Width             98.91
# RRV_DFA_alpha2                     98.91
# RRV_MFDFA_alpha2_Max               98.91
# RRV_MFDFA_alpha2_Delta             98.91
# RRV_MFDFA_alpha2_Mean              98.91
# RRV_MFDFA_alpha2_Increment         98.91
# RRV_MFDFA_alpha2_Peak              98.91
# phase                              34.09
# RRV_RMSSD                           2.91
# RRV_MeanBB                          2.91
# RRV_CVBB                            2.91
# RRV_CVSD                            2.91
# RRV_SDBB                            2.91
# RRV_SDSD                            2.91
# RRV_SD1                             2.91
# RRV_HFn                             2.91
# RRV_LFn                             2.91
# RRV_LFHF                            2.91
# RRV_HF                              2.91
# RRV_LF                              2.91
# RRV_VLF                             2.91
# RRV_MCVBB                           2.91
# RRV_MadBB                           2.91
# RRV_MedianBB                        2.91
# RRV_SD2                             2.91
# RRV_SD2SD1                          2.91
# RRV_SampEn                          2.91
# RRV_ApEn                            2.91
# std                                 0.00
# mean                                0.00
# ID                                  0.00
# median                              0.00
# min                                 0.00
# max                                 0.00
# previous_depression_diagnosis       0.00
# PHQ9-Score                          0.00
# condition                           0.00
# PHQ8-Score                          0.00
# Diagnose                            0.00
# gender                              0.00
# EMG_measuring                       0.00
# age                                 0.00
# RSP_measuring                       0.00
# ECG_measuring                       0.00
# Including_masseter                  0.00
# time                                0.00

# %%
print("---------------------------- Missing value % 3 Minute ---------------------------- \n")
missing_report = missingness_report(df_3M)
missing_report.T.sort_values("Missing_%", ascending=False)  # optional: sort top missing
# Out:
# ---------------------------- Missing value % 3 Minute ----------------------------
#                                Missing_%
# RRV_MFDFA_alpha1_Increment         99.16
# RRV_MFDFA_alpha1_Asymmetry         99.16
# RRV_MFDFA_alpha1_Fluctuation       99.16
# RRV_MFDFA_alpha1_Width             99.16
# RRV_DFA_alpha1                     99.16
# RRV_MFDFA_alpha1_Max               99.16
# RRV_MFDFA_alpha1_Delta             99.16
# RRV_MFDFA_alpha1_Mean              99.16
# RRV_MFDFA_alpha1_Peak              99.16
# RRV_MFDFA_alpha2_Width             98.11
# RRV_DFA_alpha2                     98.11
# RRV_MFDFA_alpha2_Asymmetry         98.11
# RRV_MFDFA_alpha2_Fluctuation       98.11
# RRV_MFDFA_alpha2_Delta             98.11
# RRV_MFDFA_alpha2_Max               98.11
# RRV_MFDFA_alpha2_Mean              98.11
# RRV_MFDFA_alpha2_Peak              98.11
# RRV_MFDFA_alpha2_Increment         98.11
# phase                              34.26
# RRV_MeanBB                          0.00
# RRV_CVBB                            0.00
# RRV_CVSD                            0.00
# RRV_SDBB                            0.00
# RRV_SDSD                            0.00
# RRV_RMSSD                           0.00
# median                              0.00
# max                                 0.00
# min                                 0.00
# std                                 0.00
# mean                                0.00
# RRV_SampEn                          0.00
# RRV_ApEn                            0.00
# RRV_SD2SD1                          0.00
# RRV_SD2                             0.00
# RRV_SD1                             0.00
# RRV_HFn                             0.00
# RRV_LFn                             0.00
# RRV_LFHF                            0.00
# RRV_HF                              0.00
# RRV_LF                              0.00
# RRV_VLF                             0.00
# RRV_MCVBB                           0.00
# RRV_MadBB                           0.00
# RRV_MedianBB                        0.00
# ID                                  0.00
# previous_depression_diagnosis       0.00
# PHQ9-Score                          0.00
# condition                           0.00
# PHQ8-Score                          0.00
# Diagnose                            0.00
# gender                              0.00
# EMG_measuring                       0.00
# age                                 0.00
# RSP_measuring                       0.00
# ECG_measuring                       0.00
# Including_masseter                  0.00
# time                                0.00

# %%
print("---------------------------- Missing value % 5 Minute ---------------------------- \n")
missing_report = missingness_report(df_5M)
missing_report.T.sort_values("Missing_%", ascending=False)  # optional: sort top missing
# Out:
# ---------------------------- Missing value % 5 Minute ----------------------------
#                                Missing_%
# RRV_MFDFA_alpha1_Increment         98.71
# RRV_MFDFA_alpha1_Asymmetry         98.71
# RRV_MFDFA_alpha1_Fluctuation       98.71
# RRV_MFDFA_alpha1_Width             98.71
# RRV_DFA_alpha1                     98.71
# RRV_MFDFA_alpha1_Max               98.71
# RRV_MFDFA_alpha1_Delta             98.71
# RRV_MFDFA_alpha1_Mean              98.71
# RRV_MFDFA_alpha1_Peak              98.71
# RRV_MFDFA_alpha2_Max               65.24
# RRV_MFDFA_alpha2_Mean              65.24
# RRV_MFDFA_alpha2_Peak              65.24
# RRV_MFDFA_alpha2_Fluctuation       65.24
# RRV_MFDFA_alpha2_Asymmetry         65.24
# RRV_MFDFA_alpha2_Delta             65.24
# RRV_MFDFA_alpha2_Increment         65.24
# RRV_MFDFA_alpha2_Width             65.24
# RRV_DFA_alpha2                     65.24
# phase                              34.66
# RRV_MCVBB                           0.00
# RRV_MadBB                           0.00
# RRV_MeanBB                          0.00
# RRV_SDBB                            0.00
# RRV_SDSD                            0.00
# RRV_RMSSD                           0.00
# RRV_ApEn                            0.00
# RRV_SD2SD1                          0.00
# RRV_SampEn                          0.00
# RRV_LFHF                            0.00
# RRV_LFn                             0.00
# RRV_HFn                             0.00
# RRV_SD1                             0.00
# RRV_SD2                             0.00
# RRV_LF                              0.00
# RRV_HF                              0.00
# RRV_VLF                             0.00
# RRV_CVBB                            0.00
# RRV_CVSD                            0.00
# RRV_MedianBB                        0.00
# std                                 0.00
# mean                                0.00
# ID                                  0.00
# median                              0.00
# min                                 0.00
# max                                 0.00
# previous_depression_diagnosis       0.00
# PHQ9-Score                          0.00
# condition                           0.00
# PHQ8-Score                          0.00
# Diagnose                            0.00
# gender                              0.00
# EMG_measuring                       0.00
# age                                 0.00
# RSP_measuring                       0.00
# ECG_measuring                       0.00
# Including_masseter                  0.00
# time                                0.00

# %%
df_1M.head()
# Out:
#      RRV_RMSSD   RRV_MeanBB     RRV_SDBB     RRV_SDSD  RRV_CVBB  RRV_CVSD  \
# 0  3475.717754  3551.964286  2574.618840  3617.515477  0.724844  0.978534
# 1  1449.067446  3126.200000  1069.084101  1502.284535  0.341976  0.463524
# 2  1145.499038  2806.911765   993.267512  1181.948617  0.353865  0.408099
# 3   792.294091  2955.444444   531.775768   815.990675  0.179931  0.268080
# 4   992.100761  2281.413043   730.943345  1014.801364  0.320391  0.434862
#
#    RRV_MedianBB   RRV_MadBB  RRV_MCVBB  RRV_VLF  ...  condition  Diagnose  \
# 0       2516.25  1030.40700   0.409501      0.0  ...         CR   Healthy
# 1       2791.50   526.32300   0.188545      0.0  ...         CR   Healthy
# 2       2685.50   750.19560   0.279350      0.0  ...         CR   Healthy
# 3       2951.25   580.80855   0.196801      0.0  ...         CR   Healthy
# 4       2355.50   826.54950   0.350902      0.0  ...         CR   Healthy
#
#    gender   age  EMG_measuring  RSP_measuring  ECG_measuring  \
# 0       W  22.0           Nein             Ja             Ja
# 1       W  22.0           Nein             Ja             Ja
# 2       W  22.0           Nein             Ja             Ja
# 3       W  22.0           Nein             Ja             Ja
# 4       W  22.0           Nein             Ja             Ja
#
#    Including_masseter                     time  phase
# 0                Nein  2000-01-01 17:12:16.328    NaN
# 1                Nein  2000-01-01 17:13:16.328    NaN
# 2                Nein  2000-01-01 17:14:16.328    NaN
# 3                Nein  2000-01-01 17:15:16.328    NaN
# 4                Nein  2000-01-01 17:16:16.328    NaN
#
# [5 rows x 48 columns]

# %%
# === Libraries ===
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# === Define metadata (demographic) columns to exclude ===
metadata_cols = [
    'ID', 'gender', 'age', 'condition',
    'PHQ8-Score', 'PHQ9-Score', 'previous_depression_diagnosis',
    'RSP_measuring', 'ECG_measuring', 'EMG_measuring',
    'Including_masseter', 'time', 'phase', 'window_size'
]

# === Function ===
def get_top_biosignal_features(df: pd.DataFrame, target_col: str, n_features: int = 10) -> list:
    """
    Returns the top N features most correlated with the target column.
    Correlation is measured using Pearson correlation (absolute value).
    Metadata columns are excluded.
    """
    # Drop rows with missing target
    df_clean = df.dropna(subset=[target_col]).copy()
    
    # Separate target and encode if necessary
    y = df_clean[target_col]
    if y.dtype == 'object':
        y = LabelEncoder().fit_transform(y)

    # Drop metadata columns and keep numeric biosignal features
    X = df_clean.drop(columns=[target_col] + metadata_cols, errors='ignore').select_dtypes(include='number')

    # Handle NaNs in features
    X = X.fillna(X.mean())

    # Compute Pearson correlation
    correlations = X.corrwith(pd.Series(y))
    
    # Get top N features by absolute correlation
    top_features = correlations.abs().sort_values(ascending=False).head(n_features)
    
    return top_features.index.tolist()

# %%
def plot_boxplots(df: pd.DataFrame, features: List[str], label_col: str = None):
    """
    Plot boxplots of top features, optionally grouped by class/label.
    """
    for feature in features:
        plt.figure(figsize=(6, 4))
        if label_col:
            sns.boxplot(x=label_col, y=feature, data=df)
        else:
            sns.boxplot(y=feature, data=df)
        plt.title(f"Boxplot of {feature}")
        plt.tight_layout()
        plt.show()

# %%
top_10_biosignal_features = get_top_biosignal_features(df_1M, target_col="Diagnose")
print(f"1 Minute important features:  {top_10_biosignal_features}\n")

plot_boxplots(df_1M, top_10_biosignal_features, label_col='Diagnose')
# Out:
# 1 Minute important features:  ['RRV_ApEn', 'RRV_MCVBB', 'RRV_MadBB', 'RRV_LF', 'RRV_MedianBB', 'RRV_MeanBB', 'RRV_CVBB', 'RRV_SD2', 'RRV_SDBB', 'RRV_CVSD']
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
top_10_biosignal_features = get_top_biosignal_features(df_3M, target_col="Diagnose")
print(f"3 Minute important features:  {top_10_biosignal_features}\n")

plot_boxplots(df_3M, top_10_biosignal_features, label_col='Diagnose')
# Out:
# 3 Minute important features:  ['RRV_LFn', 'RRV_MCVBB', 'RRV_SampEn', 'max', 'RRV_ApEn', 'RRV_LFHF', 'RRV_LF', 'RRV_SD2SD1', 'RRV_MedianBB', 'RRV_MadBB']

# %%
top_10_biosignal_features = get_top_biosignal_features(df_5M, target_col="Diagnose")
print(f"5 Minute important features:  {top_10_biosignal_features}\n")
plot_boxplots(df_5M, top_10_biosignal_features, label_col='Diagnose')
# Out:
# 5 Minute important features:  ['RRV_ApEn', 'RRV_MCVBB', 'RRV_MadBB', 'RRV_LF', 'RRV_MedianBB', 'RRV_MeanBB', 'RRV_CVBB', 'RRV_SD2', 'RRV_SDBB', 'RRV_CVSD']
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# === Function: top features PER condition ===
def get_top_features_per_condition(df: pd.DataFrame, target_col: str, n_features: int = 10) -> dict:
    """
    Returns the top N features most correlated with the target column, separately for each condition.
    Uses Pearson correlation (absolute value).
    """
    results = {}
    
    # Drop rows with missing target
    df_clean = df.dropna(subset=[target_col]).copy()
    
    # Loop over conditions
    for cond in df_clean['condition'].unique():
        cond_df = df_clean[df_clean['condition'] == cond]
        
        # Encode target
        y = cond_df[target_col]
        if y.dtype == 'object':
            y = LabelEncoder().fit_transform(y)
        
        # Keep only biosignal features
        X = cond_df.drop(columns=[target_col] + metadata_cols, errors='ignore').select_dtypes(include='number')
        X = X.fillna(X.mean())
        
        # Compute correlations
        correlations = X.corrwith(pd.Series(y))
        top_features = correlations.abs().sort_values(ascending=False).head(n_features)
        
        results[cond] = top_features
    
    return results


# === Example usage ===
top_features_per_cond_1 = get_top_features_per_condition(df_1M, target_col='phase', n_features=10)
# Out:
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
top_features_per_cond['ADK']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 top_features_per_cond['ADK']
#
# NameError: name 'top_features_per_cond' is not defined

# %%
top_features_per_cond_1 = get_top_features_per_condition(df_3M, target_col='phase', n_features=10)
# Out:
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
top_features_per_cond_1 = get_top_features_per_condition(df_5M, target_col='phase', n_features=10)
# Out:
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/vault/empkins/tpD/D02/.venv/lib64/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
